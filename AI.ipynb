# %%
a=1
print(a)
# Out:
# 1

# %%
# !ls
# Out:
# sample_data

# %%
# !apt-get install -y -qq software-properties-common python-software-properties module-init-tools

# !add-apt-repository -y ppa:alessandro-strada/ppa > /dev/null 2>&1

# !apt-get update -qq > /dev/null

# !apt-get install -y -qq google-drive-ocamlfuse fuse

from google.colab import auth
auth.authenticate_user()

from oauth2client.client import GoogleCredentials
creds = GoogleCredentials.get_application_default()

import getpass
import os

os.system(f"google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret}")

vcode = getpass.getpass('Enter the verification code: ')

os.system(f"echo {vcode} | google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret}")
# Out:
# E: Package 'python-software-properties' has no installation candidate
# E: Package 'module-init-tools' has no installation candidate
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Selecting previously unselected package google-drive-ocamlfuse.
# (Reading database ... 126675 files and directories currently installed.)
# Preparing to unpack .../google-drive-ocamlfuse_0.7.32-0ubuntu5~bpo22.04.1_amd64.deb ...
# Unpacking google-drive-ocamlfuse (0.7.32-0ubuntu5~bpo22.04.1) ...
# Setting up google-drive-ocamlfuse (0.7.32-0ubuntu5~bpo22.04.1) ...
# Processing triggers for man-db (2.10.2-1) ...
# Enter the verification code: ··········
# 256

# %%
# !mkdir -p drive
# !google-drive-ocamlfuse drive
# Out:
# Thread 1 killed on uncaught exception Unix.Unix_error(50, "bind", "")
# /usr/bin/xdg-open: 882: www-browser: not found
# /usr/bin/xdg-open: 882: links2: not found
# /usr/bin/xdg-open: 882: elinks: not found
# /usr/bin/xdg-open: 882: links: not found
# /usr/bin/xdg-open: 882: lynx: not found
# /usr/bin/xdg-open: 882: w3m: not found
# xdg-open: no method available for opening 'https://accounts.google.com/o/oauth2/auth?client_id=None&redirect_uri=http%3A%2F%2F127.0.0.1%3A8080%2Foauth2callback&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force'
# /bin/sh: 1: firefox: not found
# /bin/sh: 1: google-chrome: not found
# /bin/sh: 1: chromium-browser: not found
# /usr/bin/open: 882: www-browser: not found
# /usr/bin/open: 882: links2: not found
# /usr/bin/open: 882: elinks: not found
# /usr/bin/open: 882: links: not found
# /usr/bin/open: 882: lynx: not found
# /usr/bin/open: 882: w3m: not found
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !is
# Out:
# /bin/bash: line 1: is: command not found

# %%
import os
os.chdir("drive")

# %%
os.chdir("../")

# %%
# !pythone xxx.py
# Out:
# /bin/bash: line 1: pythone: command not found

# %%
import os

project_path = 'drive/Colab/Your project folder'

if os.path.exists(project_path):
    os.chdir(project_path)
    print("Changed working directory to:", os.getcwd())
else:
    print(" Directory does not exist:", project_path)
# Out:
#  Directory does not exist: drive/Colab/Your project folder

# %%
# !python xxx.py
# Out:
# python3: can't open file '/content/xxx.py': [Errno 2] No such file or directory
